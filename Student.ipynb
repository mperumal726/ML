# %%
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Students.csv')
df
# Out:
#     Hours  Marks
# 0       0     34
# 1       1     36
# 2       1     33
# 3       1     39
# 4       1     42
# 5       2     45
# 6       2     38
# 7       3     45
# 8       3     53
# 9       3     46
# 10      3     56
# 11      4     59
# 12      4     55
# 13      4     56
# 14      5     72
# 15      5     59
# 16      6     62
# 17      6     71
# 18      7     78
# 19      7     88
# 20      7     61
# 21      7     74
# 22      8     71
# 23      8     89
# 24      9     82
# 25      9     67
# 26      9     89
# 27     10     81
# 28     10     82
# 29     11     79

# %%
x=df['Hours'].values.reshape(-1,1)
y=df['Marks'].values.reshape(-1,1)

# %%
y
# Out:
# array([[34],
#        [36],
#        [33],
#        [39],
#        [42],
#        [45],
#        [38],
#        [45],
#        [53],
#        [46],
#        [56],
#        [59],
#        [55],
#        [56],
#        [72],
#        [59],
#        [62],
#        [71],
#        [78],
#        [88],
#        [61],
#        [74],
#        [71],
#        [89],
#        [82],
#        [67],
#        [89],
#        [81],
#        [82],
#        [79]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=30,random_state=42)
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2562, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2559 arrays = indexable(*arrays)
#    2561 n_samples = _num_samples(arrays[0])
# -> 2562 n_train, n_test = _validate_shuffle_split(
#    2563     n_samples, test_size, train_size, default_test_size=0.25
#    2564 )
#    2566 if shuffle is False:
#    2567     if stratify is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_split.py:2181, in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2173 train_size_type = np.asarray(train_size).dtype.kind
#    2175 if (
#    2176     test_size_type == "i"
#    2177     and (test_size >= n_samples or test_size <= 0)
#    2178     or test_size_type == "f"
#    2179     and (test_size <= 0 or test_size >= 1)
#    2180 ):
# -> 2181     raise ValueError(
#    2182         "test_size={0} should be either positive and smaller"
#    2183         " than the number of samples {1} or a float in the "
#    2184         "(0, 1) range".format(test_size, n_samples)
#    2185     )
#    2187 if (
#    2188     train_size_type == "i"
#    2189     and (train_size >= n_samples or train_size <= 0)
#    2190     or train_size_type == "f"
#    2191     and (train_size <= 0 or train_size >= 1)
#    2192 ):
#    2193     raise ValueError(
#    2194         "train_size={0} should be either positive and smaller"
#    2195         " than the number of samples {1} or a float in the "
#    2196         "(0, 1) range".format(train_size, n_samples)
#    2197     )
#
# ValueError: test_size=30 should be either positive and smaller than the number of samples 30 or a float in the (0, 1) range
